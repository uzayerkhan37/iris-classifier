# %%
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

print("Setup Complete! Ready to build the AI model.")
# Out:
# Setup Complete! Ready to build the AI model.

# %%
from sklearn.datasets import load_iris
import pandas as pd

# Fetch and structure the data
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

# Review the first 5 entries
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
